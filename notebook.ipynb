# %%
# Out:
# [1, 2, 3]

# %%
a = 256
b = 256

print(a == b)
print(a is b)
# Out:
# True
# True

# %%
import copy

a = [1,2,3]

b = copy.copy(a)
c = copy.deepcopy(a)

# %%
a[0].append(4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 a[0].append(4)
#
# AttributeError: 'int' object has no attribute 'append'

# %%
def add_item(item, items=[]):
    items.append(item)
    return items

print(add_item(1))
print(add_item(2))
# Out:
# [1]
# [1, 2]

# %%
def add_num(int):
    int += 100



x = 5
add_num(x)
# Out:
# None

# %%
scores = [90, 80, 70, 60, 50]
filitered_scores = []
for score in scores:
    if score > 70:
        filitered_scores.append(score)

print(filitered_scores)
# Out:
# [90, 80]

# %%
filitered_scores = [score*2 for score in scores if score < 70]
filitered_scores
# Out:
# [120, 100]

# %%
filitered_scores = [score if score == 50 else "Not 50" for score in scores]

# %%
filitered_scores
# Out:
# ['Not 50', 'Not 50', 'Not 50', 'Not 50', 50]

# %%
dic = {"asd": "sada"}

print (dic.values())
# Out:
# dict_values(['sada'])

# %%
scores = {"score1": 90, "score2": 80}

# %%
for k,v in scores.items():
    if v == 90: 
        print (k,v)
# Out:
# score1 90

# %%
[k for k,v in scores.items() if v==90]
# Out:
# ['score1']

# %%
squares = {}

for number in range(5):
    squares[number] = number **2

# %%
squares ={}

# %%
{key:value**2 for key,value in scores.items()}
# Out:
# {'score1': 8100, 'score2': 6400}

# %%
from collections import Counter

words = [
    "python",
    "ai",
    "python",
    "rag",
    "python",
]

counts = Counter(words)

print(counts)
# Out:
# Counter({'python': 3, 'ai': 1, 'rag': 1})

# %%
list = [1,2,3]

iterator = iter(list)

# %%
for x in list:
    print(next(iterator))
# Out:
# 1
# 2
# 3

# %%
def get_numbers():
    yield 1
    yield 2
    yield 3

numbers = get_numbers()

# %%
list = [1,2,3]
list2 = ["a","b","c"]

test = zip(list,list2)

# %%
new_list = []

for x,y in zip(list,list2):
    new_list.append((x,y))

# %%
new_list
# Out:
# [(1, 'a'), (2, 'b'), (3, 'c')]

# %%
list = [1,6,3,4,123]
new = sorted(list)

# %%
list
# Out:
# [1, 6, 3, 4, 123]

# %%
new
# Out:
# [1, 3, 4, 6, 123]

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# Build a small AI agent exposed through a FastAPI endpoint.
#
# The user can send questions such as:
#
# "What is the email address of user 3?"
#
# The agent should decide whether it needs to call an external API. If necessary, it should call the JSONPlaceholder users API to retrieve the user information and then use the LLM to answer the user's question.
#
# Build this using FastAPI, Pydantic, LangGraph, and an LLM with tool calling.

# %%
import fastapi

#Pydantic class for API calls and LLM outputs


#Get api to access user info


#

#Define the functions (nodes)


#Build the grpah
